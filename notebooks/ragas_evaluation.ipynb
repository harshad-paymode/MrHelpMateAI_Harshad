# %% [markdown]
# ## DeepEval Evaluation

# %% [markdown]
# python -m ipykernel install --user --name=myenv --display-name="Python (myenv)"

# %%
## Imports
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))

#DeepEval
import pandas as pd
import time
import os

from src.retrieval import format_docs_with_metadata, rerank_documents
from src.prompts import get_prompt_template
from src.core.models import get_retriever, get_generator, get_reranker
from langchain_community.retrievers import BM25Retriever
from langchain_mistralai import ChatMistralAI
from langchain_openai import AzureChatOpenAI
from deepeval.models.base_model import DeepEvalBaseLLM
from deepeval import evaluate
from deepeval.test_case import LLMTestCase, LLMTestCaseParams
from deepeval.metrics import GEval
from deepeval.metrics import AnswerRelevancyMetric, ContextualPrecisionMetric, FaithfulnessMetric, ContextualRecallMetric

import ast
import json
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Creating Synthetic Dataset for RAGAS
#
# #### **Specific vs. Abstract Queries in a RAG:<br>**
#
# **Specific Query:** Focuses on clear, fact-based retrieval. The goal in RAG is to retrieve highly relevant information from one or more documents that directly address the specific question.
#
# **Abstract Query:** Requires a broader, more interpretive response. In RAG, abstract queries challenge the retrieval system to pull from documents that contain higher-level reasoning, explanations, or opinions, rather than simple facts.

# %%
#Design the prompt to generate QA pair
os.environ['MISTRAL_API_KEY'] = os.getenv("MISTRAL_API")
llm_qa = ChatMistralAI(
    model=os.getenv("MODEL_QA_GENERATOR"),
    temperature=0,
    max_retries=2,
    )
def get_qa_pair(Content):
    messages = [{"role":"system","content":f"""You are an experienced Insurance Consultant. Your task is to generate difficult Question–Answer pairs from the given policy document.

            You are given:
            - A block of Content text from that section.

            An **Abstract Query** is a question that requires interpretation, reasoning, or combining multiple ideas from the text. It must NOT be answerable by copying a single sentence.

            Follow these rules strictly:
            1. You must create ONLY abstract queries as defined above.
            2. Each question must include at least two policy terms or phrases that appear verbatim in the provided content (e.g., defined terms, or key policy phrases).
            3. Use ONLY the provided content. Do NOT guess or use outside knowledge.
            4. Keep both questions and answers concise and precise.
            5. Each query must be at most 2 sentences and must not exceed 50 words.
            6. Return a JSON array of exactly two objects in this format:
            {json.dumps([{"query": "...", "answer": "..."}, {"query": "...", "answer": "..."}])}
            7. NEVER return more than two pairs. If more are possible, choose the two most important.

            Content:
            {Content}

            Generate exactly 2 abstract QA pairs based on the above.
            Return ONLY the JSON array and nothing else.
        """}
        ]
    
    ai_msg = llm_qa.invoke(messages)
    return ai_msg.content

# %%
chunks = pd.read_csv(os.getenv("CLEANED_DF"))
#Combine chunks for similar sub level headings to pass to QA generator

combined_chunks = {}
for index, row in chunks.iterrows():
    meta_dic = ast.literal_eval(row['Metadata'])
    part = meta_dic['PART_DETAILS']
    section = meta_dic['SECTION_DETAILS']
    article = meta_dic['ARTICLE_DETAILS']
    combined_chunks.setdefault(f"Part: {part}, Section: {section}, Article: {article}", []).append(row['Text'])

for key, value in combined_chunks.items():
    combined_chunks[key] = ''.join(combined_chunks[key])

# %%
#Let's generate the content one by one
all_qa_pairs = []
count = 20
for heading , content in combined_chunks.items():
    if count == 0:
        break
    response = get_qa_pair(content)
    all_qa_pairs.append(response)
    count-=1

# %%
#Post processing all the responses
all_qa_pairs_cleaned=[]
for response in all_qa_pairs:
    clean_response = response.replace("\n","").replace("json",'').replace("  ","").replace("```","").strip()
    try:
        list_qa = json.loads(clean_response)
        all_qa_pairs_cleaned.append(list_qa)
    except:
        print("Not able to load this pair",response)

# %%
qa_df = pd.DataFrame(columns = ['query','answer'])
for qa_pair in all_qa_pairs_cleaned:
    for dict_qa in qa_pair:
        qa_df = pd.concat([qa_df,pd.DataFrame(dict_qa,index=[len(qa_df)+1])])
qa_df = qa_df.rename(columns={'answer':'expected_output'})

# %%
qa_df.to_parquet(os.getenv("OUTPUT_QA"),index=False)
qa_df.head()
# Out:
#                                                query  \
# 1  How does the policy define a Member's ability ...
# 2  What criteria must a Dependent Child meet to q...
# 3  How does the Group Policy define the contractu...
# 4  What constitutes the entire contract under thi...
# 5  What conditions must be met for changes to the...
#
#                                      expected_answer
# 1  A Member is Actively at Work if able and avail...
# 2  A Dependent Child must be under 26 and meet sp...
# 3  The Principal's obligations are solely defined...
# 4  The entire contract consists of the Group Poli...
# 5  Changes to the Group Policy must be in Writing...

# %% [markdown]
# ## Retrieve LLM Response + Retrievals

# %%
os.environ['MISTRAL_API_KEY'] = os.getenv("MISTRAL_API")
llm_gen = ChatMistralAI(
    model= os.getenv("MODEL_GENERATOR"),
    temperature=0,
    max_retries=2
    ).with_fallbacks(
        [
            ChatMistralAI(model = os.getenv("MODEL_BACKUP_1"), temperature = 0, max_retries=2),
            ChatMistralAI(model = os.getenv("MODEL_BACKUP_2"), temperature = 0, max_retries=2)
        ]
    )
def get_response(query):
    chroma_retriever = get_retriever()
    retrieved_docs =  chroma_retriever.invoke(query)
    bm25_docs_retrieved = BM25Retriever.from_documents(retrieved_docs, k=len(retrieved_docs)).invoke(query)
    results_df = format_docs_with_metadata(bm25_docs_retrieved)
    top_docs_and_context = rerank_documents(query,results_df)
    metadatas = top_docs_and_context['Documents']
    context = top_docs_and_context['Metadatas']
    prompt = get_prompt_template().format_messages(query=query, context=context, metadatas=metadatas)
    response = llm_gen.invoke(prompt)
    return top_docs_and_context['Documents'],response.content

# %%
qa_df = pd.read_parquet(os.getenv("OUTPUT_QA"))
qa_df['actual_output'] = ""
qa_df['retrieval_context'] = [[] for _ in range(len(qa_df))]

for idx, row in qa_df.iterrows():
    try:
        retrieved_context, response = get_response(row["query"])
        qa_df.at[idx, "retrieval_context"] = retrieved_context
        qa_df.at[idx, "actual_output"] = response
    except Exception as e:
        qa_df.at[idx, "retrieval_context"] = []
        qa_df.at[idx, "actual_output"] = f"ERROR: {str(e)}"

qa_df['retrieval_context'] = qa_df['retrieval_context'].apply(lambda x: x.to_list())
qa_df.to_parquet(os.getenv("OUTPUT_QA"))
# Out:
# 2026-01-14 01:57:57 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:58:02 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:58:02 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 01:58:17 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:58:21 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:58:21 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 01:58:28 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:58:33 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:58:33 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 01:58:47 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:58:51 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:58:52 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 01:59:02 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:59:06 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:59:06 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 01:59:17 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:59:21 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:59:22 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 01:59:31 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:59:36 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:59:36 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 01:59:40 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:59:45 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:59:45 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 01:59:53 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 01:59:57 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 01:59:57 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:00:06 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:00:10 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:00:10 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:00:19 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:00:24 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:00:24 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:00:37 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:00:42 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:00:42 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:00:49 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:00:54 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:00:54 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:01:05 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:01:10 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:01:10 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:01:19 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:01:24 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:01:24 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:01:39 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:01:44 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:01:45 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:01:54 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:01:59 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:01:59 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:02:03 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:02:07 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:02:08 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:02:20 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:02:24 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:02:25 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:02:36 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:02:41 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:02:41 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:02:53 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:02:57 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:02:57 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:03:09 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:03:16 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:03:17 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:03:29 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:03:33 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:03:33 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:03:41 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:03:45 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:03:45 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:03:52 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:03:57 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:03:57 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:04:08 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:04:13 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:04:13 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:04:22 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:04:28 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:04:29 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:04:36 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:04:40 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:04:40 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:04:50 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:04:54 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:04:55 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:05:07 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:05:12 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:05:12 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:05:27 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:05:32 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:05:32 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:05:39 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:05:43 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:05:43 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:05:52 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:05:56 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:05:56 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:06:04 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:06:09 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:06:09 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:06:21 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:06:26 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:06:26 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:06:34 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:06:39 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:06:39 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:06:46 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:06:51 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:06:51 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:07:00 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:07:04 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:07:05 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:07:14 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:07:18 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:07:19 INFO MrHelpMateAI Chunk Results fetche with size 3
# 2026-01-14 02:07:26 INFO MrHelpMateAI Chroma Retriever is Created!
# 2026-01-14 02:07:30 INFO MrHelpMateAI Reranker Created!
# 2026-01-14 02:07:30 INFO MrHelpMateAI Chunk Results fetche with size 3

# %% [markdown]
# ### Configuring Azure AI

# %%
class AzureOpenAI(DeepEvalBaseLLM):
    def __init__(
        self,
        model
    ):
        self.model = model

    def load_model(self):
        return self.model

    def generate(self, prompt: str) -> str:
        chat_model = self.load_model()
        return chat_model.invoke(prompt).content

    async def a_generate(self, prompt: str) -> str:
        chat_model = self.load_model()
        res = await chat_model.ainvoke(prompt)
        return res.content

    def get_model_name(self):
        return "gpt-40"

# Replace these with real values
custom_model = AzureChatOpenAI(
    openai_api_version=os.getenv("OPENAI_API_VERSION"),
    azure_deployment=os.getenv("OPENAI_MODEL"),
    azure_endpoint=os.getenv("AZURE_ENDPOINT"),
    openai_api_key=os.getenv("OPENAI_KEY"),
)
azure_openai = AzureOpenAI(model=custom_model)
print(azure_openai.generate("Write me a joke"))
# Out:
# Sure! Here's a joke for you:
#
# Why don’t skeletons fight each other?
#
# Because they don’t have the guts!

# %% [markdown]
# ## Mistral as a Judge

# %%
#Mistral as a Judge

# from mistralai import Mistral
# from deepeval.models.base_model import DeepEvalBaseLLM

# class MistralAPI(DeepEvalBaseLLM):
#     def __init__(self, api_key):
#         self.client = Mistral(api_key=api_key)

#     def load_model(self):
#         return self.client   # required by DeepEval

#     def generate(self, prompt: str) -> str:
#         resp = self.client.chat.complete(
#             model=os.getenv("MODEL_JUDGE"),
#             messages=[{"role": "user", "content": prompt}],
#             temperature=0.3
#         )
#         return resp.choices[0].message.content

#     async def a_generate(self, prompt: str) -> str:
#         return self.generate(prompt)

#     def get_model_name(self):
#         return "Mistral-API"


# mistral = MistralAPI(api_key = os.getenv("MODEL_API"))
# print(mistral.generate("Tell me a joke"))

# %%
all_test_cases_df = pd.read_parquet(os.getenv("OUTPUT_QA"))

contextual_precision  = ContextualPrecisionMetric(
    threshold=0.7,
    model=azure_openai,
    include_reason=True
)

answer_relevancy = AnswerRelevancyMetric(threshold=0.7,model=azure_openai,include_reason=True)

contextual_Recall = ContextualRecallMetric(
    threshold=0.7,
    model=azure_openai,
    include_reason=True
)

faithfullness = FaithfulnessMetric(
    threshold=0.7,
    model=azure_openai,
    include_reason=True
)

test_cases = []

for _, row in all_test_cases_df.iterrows():
    if row["contextual_precision"]["score"] == None:
        test_cases.append(
            LLMTestCase(
                input=row["query"],
                actual_output=row["actual_output"],
                expected_output=row["expected_output"],
                retrieval_context=list(row["retrieval_context"])
            )
        )

# %%
all_results = []
for i in range(2):
    subset_test = test_cases[i*4:i*4+4]
    results = evaluate(
        test_cases=subset_test,
        metrics=[
            contextual_precision,
            answer_relevancy,
            contextual_Recall,
            faithfullness
        ]
    )
    all_results.append(results)
    time.sleep(60)
# Out:
# ✨ You're running DeepEval's latest Contextual Precision Metric! (using gpt-40, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-40, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Contextual Recall Metric! (using gpt-40, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-40, strict=False, async_mode=True)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the first node directly addresses the input question with detailed information, while the irrelevant nodes, such as the second discussing timelines under ERISA and the third describing proof of loss, are appropriately ranked lower., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the output directly addresses the input without any irrelevant statements, demonstrating complete relevance and clarity. Great job!, error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the expected output perfectly aligns with the node(s) in retrieval context, showing a clear and precise match. Great work—keep it up!, error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because there are no contradictions and the actual output is perfectly faithful to the retrieval context. Great job!, error: None)
#
# For test case:
#
#   - input: What role do the Claims Procedures play in the finality of The Principal's decisions regarding benefits?
#   - actual output: The Claims Procedures establish the framework that governs how The Principal reviews, decides, and finalizes benefit determinations. Under these procedures:
#
# - **The Principal retains full discretionary authority** to interpret the policy terms and make final decisions on claims, including the approval or denial of benefits. This means that once The Principal issues a decision following the Claims Procedures, that decision is considered final and binding, subject only to the appeals process outlined in the procedures.
#
# - The Claims Procedures also define **specific timelines and steps** (such as the initial review period and appeal rights) that must be followed before a decision becomes final. For example, if a claimant does not appeal a denial within the specified timeframe, The Principal’s decision stands as the final determination of benefits.
#
# - Additionally, the procedures ensure compliance with regulatory requirements (such as ERISA, where applicable), which further solidifies the finality of The Principal’s decisions once all procedural steps are exhausted.
#
# In summary, the Claims Procedures provide the structured process that leads to the finality of The Principal’s decisions, ensuring that determinations are made fairly, consistently, and in accordance with policy terms and legal standards.
#
# ---
#
# ### **Citations**
# 1. **Part:** *PART II - POLICY PROVISIONS*
#    **Page:** *11*
#    **Text Referred:**
#    *"The Principal has complete discretion to construe the terms of this policy and to make final determinations on claims for benefits."*
#
# 2. **Section:** *Section D - CLAIMS PROCEDURES*
#    **Page:** *53*
#    **Text Referred:**
#    *"ERISA permits up to 45 days from receipt of claim for The Principal to make an initial determination, with extensions allowed under specific circumstances. The decision issued at the end of this period is final unless appealed as per the procedures outlined."*
#
# 3. **Part:** *PART IV - BENEFITS*
#    **Page:** *53*
#    **Text Referred:**
#    *"The Principal, when it receives notice of claim, will review the claim in accordance with the Claims Procedures. The decision rendered after such review shall be final unless the claimant submits an appeal within the timeframe specified."*
#   - expected output: The Principal's decisions are final and binding, but they are subject to the Claims Procedures outlined in PART IV, Section D of the policy.
#   - context: None
#   - retrieval context: ['T he Principal has complete discretion to construe or interpret the provisions of this group insurance policy, to determine eligibility for benefits, and to determine the type and extent of benefits, if any, to be provided. The decisions of The Principal in such matters shall be controlling, binding and final as between The Principal and persons covered by this Group Policy, subject to the Claims Procedures in PART IV, Section D.', 'ERISA permits up to 45 days from receipt of claim for processing the claim. If a claim cannot be processed due to incomplete information, The Principal will send a Written explanation prior to the expiration of the 45 days. The claimant is then allowed up to 45 days to provide all additional information requested. The Principal is permitted two 30-day extensions for processing an incomplete claim. Written notification will be sent to the claimant regarding the extension. In actual practice, benefits under this Group Policy will be payable sooner, provided The Principal receives complete and proper proof of loss. Further, if a claim is not payable or cannot be processed, The Principal will submit a detailed explanation of the basis for its denial. This policy has been updated effective January 1, 2014 GC 6018 Section D - Claim Procedures, Page 1', 'The Principal, when it receives notice of claim, will provide appropriate claim forms for filing proof of loss. If the forms are not provided within 15 days after The Principal receives notice, the person will be considered to have complied with the requirements of this Group Policy upon submitting, within the time specified below for filing proof of loss, Written proof covering the occurrence, character, and extent of the loss.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 100.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Contextual Recall: 100.00% pass rate
# Faithfulness: 75.00% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the most relevant node in the retrieval contexts, found in the first node, is perfectly ranked at the top. It provides a precise and clear explanation by stating, 'In the absence of fraud, after this Group Policy has been in force two years, The Principal may not contest its validity except for nonpayment of premium.' Great job!, error: None)
#   - ✅ Answer Relevancy (score: 0.8181818181818182, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.82 because the output mostly addresses the question but includes irrelevant statements about representations and warranties and material statements in written applications, which do not directly clarify how fraud impacts the contestability of the policy after two years., error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the expected output is perfectly supported by the 1st node in the retrieval context, with no opposing evidence. Fantastic match!, error: None)
#   - ✅ Faithfulness (score: 0.75, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.75 because the actual output specifies an exclusion for periods of disability and a requirement for statements in written applications, which are not aligned with the retrieval context that lacks these details or specifies slightly different requirements., error: None)
#
# For test case:
#
#   - input: How does the presence of fraud affect The Principal's ability to contest the Group Policy's validity after it has been in force for two years?
#   - actual output: After your Group Policy has been in force for two years, **The Principal generally cannot contest its validity**—**except in cases of fraud**. If fraud is discovered, The Principal retains the right to challenge the policy’s validity even after the two-year period, as fraud invalidates the usual protections that limit contestability.
#
# Here’s how it works:
# - **Without fraud**: After two years, the policy becomes incontestable, meaning The Principal cannot void it based on misstatements or omissions in the application.
# - **With fraud**: The Principal can contest the policy at any time, regardless of how long it has been in force, because fraud undermines the integrity of the contract.
#
# **Key takeaway**: Fraud removes the two-year time limit on The Principal’s ability to challenge the policy’s validity.
#
# ---
# ### **Citations**
# 1. **Document Reference**:
#    *"In the absence of fraud, after this Group Policy has been in force for two years (excluding any period during which a Member was Disabled), The Principal will not contest the validity of this Group Policy..."*
#    - **Part**: PART II - POLICY ADMINISTRATION
#    - **Section**: Section A - Contract
#    - **Article**: Article 1: Entire Contract; Changes
#    - **Page**: Not specified in metadata
#
# 2. **Supporting Context**:
#    *"All statements made by any individual insured under the Group Policy are deemed representations and not warranties. No statement will be used to void the insurance or deny a claim unless it is material and contained in a written application."*
#    - **Part**: Not specified
#    - **Section**: Section A - Contract
#    - **Article**: Article 2: Time Limit on Certain Defenses
#    - **Page**: Not specified
#   - expected output: In the absence of fraud, The Principal cannot contest the Group Policy's validity after two years, except for nonpayment of premium.
#   - context: None
#   - retrieval context: ['In the absence of fraud, after this Group Policy has been in force two years, The Principal may not contest its validity except for nonpayment of premium.', "All statements made by any individual insured under this Group Policy will be representations and not warranties. In the absence of fraud, these statements may not be used to contest an insured person's insurance unless: a. the insured person's insurance has been in force for less than two years during the insured's lifetime; and b. the statement is in Written form Signed by the insured person; and This policy has been updated effective January 1, 2014 GC 6003 Section A - Contract, Page 2", "The Principal may at any time terminate a Member's or Dependent's eligibility under the Group Policy: a. in Writing and with 31-day notice, if the individual submits any claim that contains false or fraudulent elements under state or federal law; or b. in Writing and with 31-day notice, upon finding in a civil or criminal case that a Member or Dependent has submitted claims that contain false or fraudulent elements under state or federal law; or c. in Writing and with 31-day notice, when a Member or Dependent has submitted a claim which, in good faith judgement and investigation, a Member or Dependent knew or should have known, contains false or fraudulent elements under state or federal law."]
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 100.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Contextual Recall: 100.00% pass rate
# Faithfulness: 75.00% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the first node in the retrieval contexts quotes, 'The delivery of such Certificates will be in either paper or electronic format... They will not be considered a part of this Group Policy,' directly answering the input, and no irrelevant nodes are ranked higher., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the answer is completely relevant, with no irrelevant statements present in the output. Great job on providing a focused and accurate response!, error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because every part of the expected output aligns perfectly with the first node in the retrieval context. Great job maintaining complete consistency!, error: None)
#   - ✅ Faithfulness (score: 0.8823529411764706, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.88 because the actual output inaccurately claims that the Certificate is not an independent contract and is an extension of the Group Policy, while the retrieval context explicitly mentions that the Certificate will not be considered a part of the Group Policy. These contradictions slightly detract from the overall faithfulness but do not entirely undermine it., error: None)
#
# For test case:
#
#   - input: How does the delivery of Certificates to insured Members impact the status of the Group Policy?
#   - actual output: The delivery of Certificates to insured Members does not alter the fundamental status of the **Group Policy** itself. The Group Policy remains the primary contract between the Principal (insurer) and the Policyholder, governing the overall terms, conditions, and coverage for the entire group. However, the Certificates serve as **evidence of insurance** for individual Members under the Group Policy. Here’s how their delivery impacts the arrangement:
#
# 1. **Individual Coverage Activation**:
#    Once a Certificate is delivered to an insured Member, it confirms that the Member is covered under the Group Policy, subject to the terms outlined in the Certificate and the Group Policy. The Member’s coverage becomes effective as specified in the Certificate (e.g., upon receipt or a designated date).
#
# 2. **Dependence on the Group Policy**:
#    The Certificate is **subordinate** to the Group Policy. If the Group Policy is terminated, modified, or lapses, the coverage provided by the Certificate is automatically affected, regardless of whether the Certificate was delivered. The Certificate’s validity is contingent on the Group Policy remaining in force.
#
# 3. **No Independent Status**:
#    The Certificate does not create a separate or independent contract. It is an extension of the Group Policy, and its terms cannot override or conflict with the Group Policy. For example, if the Group Policy excludes certain risks, the Certificate cannot provide coverage for those risks.
#
# 4. **Policyholder’s Obligations**:
#    The Policyholder is responsible for distributing Certificates to insured Members, but this act does not change the Group Policy’s status. The Policyholder must ensure that Certificates are delivered in accordance with the Group Policy’s requirements (e.g., timelines, accuracy of details).
#
# In summary, while the delivery of Certificates is critical for confirming individual coverage, it does not impact the **legal or operational status** of the Group Policy. The Group Policy remains the governing document, and the Certificates are merely instruments to communicate coverage details to Members.
#
# ---
# ### Citations:
# 1. **Part**: PART II - POLICY ADMINISTRATION
#    **Section**: Section A - Contract
#    **Article**: N/A
#    **Page**: [Not explicitly mentioned in the provided metadata]
#    **Reference**: *"This Group Policy, the current Certificate, the Application of the Policyholder, and the individual Applications of the Members (if any) constitute the entire contract between the parties."* [^1]
#
# 2. **Part**: [Not explicitly mentioned in the provided metadata]
#    **Section**: Section F, Article 1
#    **Article**: Article 1
#    **Page**: [Not explicitly mentioned in the provided metadata]
#    **Reference**: *"The Principal will give the Policyholder Certificates for delivery to each insured Member. The Certificate will state the benefits, terms, and conditions applicable to the Member’s coverage under the Group Policy."* [^2]
#
# [^1]: Metadata: `{'SECTION_DETAILS': 'Section A - Contract', 'page': None, 'part': None, 'article': None}`
# [^2]: Metadata: `{'SECTION_DETAILS': 'Section F, Article 1, will be provided by the Principal to the Policyholder for delivery to each insured Member', 'page': None, 'part': None, 'article': 'Article 1'}`
#   - expected output: The delivery of Certificates, whether in paper or electronic format, does not alter the Group Policy as they are not considered part of it.
#   - context: None
#   - retrieval context: ['The Principal will give the Policyholder Certificates for delivery to insured Members. The delivery of such Certificates will be in either paper or electronic format. The Certificates will be evidence of insurance and will describe the basic features of the coverage. They will not be considered a part of this Group Policy.', 'This Group Policy, the current Certificate, the attached Policyholder application, and any Member applications make up the entire contract. The Principal is obligated only as provided in this Group Policy and is not bound by any trust or plan to which it is not a signatory party.', "A beneficiary should be named at the time a Member applies or enrolls under this Group Policy. A Member may name or later change a named beneficiary by sending a Written request to The Principal. A change will not be effective until recorded by The Principal. Once recorded, the change will apply as of the date the request was Signed. If The Principal properly pays any benefit before a change request is received, that payment may not be contested. Further: a. The naming of a new beneficiary in an application for individual purchase under PART III, Policy. b. If a Member's terminated insurance is reinstated, his or her beneficiary will be as recorded on the date of termination. If a Member is insured under this Group Policy on its Date of Issue and this insurance replaces insurance in force on the day immediately before the Date of Issue, the beneficiary named in such replaced insurance and recorded by the Policyholder or The Principal will be the beneficiary under this Group Policy until a new beneficiary is named."]
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 100.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Contextual Recall: 100.00% pass rate
# Faithfulness: 75.00% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the relevant node explaining 'changes must be in Writing and Signed by an officer of The Principal' is ranked first, while the irrelevant nodes related to 'termination responsibilities' and 'changes to a Member's Scheduled Benefit' are correctly ranked lower. Great job ensuring relevance is prioritized!, error: None)
#   - ✅ Answer Relevancy (score: 0.8333333333333334, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.83 because the output addresses some aspects of the topic, such as related information about the Policyholder and group members, but includes irrelevant details that do not directly clarify the conditions for Group Policy changes or how the Policyholder's consent is involved., error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because every sentence from the expected output is perfectly supported by the details found in the 1st node in retrieval context. Excellent alignment!, error: None)
#   - ❌ Faithfulness (score: 0.5833333333333334, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.58 because the actual output contradicts the retrieval context, which repeatedly emphasizes that changes to the Group Policy can be made without the Policyholder's or members' consent, as long as they are documented in writing between The Principal and the Policyholder. Despite these clear statements, the actual output incorrectly claims otherwise., error: None)
#
# For test case:
#
#   - input: What conditions must be met for changes to the Group Policy to be effective, and how does the Policyholder's consent relate to these changes?
#   - actual output: For changes to the **Group Policy** to be effective, the following conditions must generally be met:
#
# 1. **Written Agreement of the Policyholder**:
#    Any modifications to the Group Policy typically require the **written consent of the Policyholder**. The insurer cannot unilaterally alter the terms of the policy without this agreement.
#
# 2. **Formal Endorsement or Amendment**:
#    Changes must be documented through a **formal endorsement or amendment** to the policy, which is then issued by the insurer. This ensures that the modifications are legally binding and clearly communicated.
#
# 3. **Compliance with Legal and Regulatory Requirements**:
#    Any changes must comply with applicable **laws, regulations, and contractual obligations** governing the policy.
#
# 4. **Notification to Affected Parties**:
#    The Policyholder is usually responsible for informing **covered members (e.g., employees or group participants)** about material changes to the policy, particularly if those changes impact their benefits or coverage.
#
# ### Role of the Policyholder’s Consent:
# - The **Policyholder’s consent is mandatory** for most changes to the Group Policy. Without it, modifications proposed by the insurer may not take effect.
# - The Policyholder acts as the **representative of the group** (e.g., employer or association) and must approve changes that affect the terms, benefits, or premiums of the policy.
# - In some cases, the Policyholder may also need to **consult with or obtain approval from the group members** (e.g., employees) if the changes significantly impact their coverage.
#
# Would you like further clarification on any specific type of change (e.g., premium adjustments, benefit modifications, or termination)?**
#
# ---
# ### **Citations:**
# 1. **Part:** PART II - POLICY ADMINISTRATION
#    **Article:** Article 4 - Policyholder
#    **Page:** [Not explicitly mentioned in the provided metadata]
#    *(Reference: Conditions for policy modifications and the Policyholder’s role in consenting to changes.)*
#
# 2. **Part:** [Not explicitly mentioned in the provided metadata]
#    **Article:** Article 1 - Member Life Insurance
#    **Page:** [Not explicitly mentioned in the provided metadata]
#    *(Reference: General framework for policy terms and conditions, including amendments.)*
#   - expected output: Changes to the Group Policy must be in Writing and Signed by an officer of The Principal to be effective. The Policyholder's consent is not required for any changes, including those regarding coverage, benefits, and participation privileges, and payment of premium beyond the effective date of the change constitutes the Policyholder's consent.
#   - context: None
#   - retrieval context: ["Insurance under this Group Policy runs annually to the Policy Anniversary, unless sooner terminated. No agent, employee, or person other than an officer of The Principal has authority to change this Group Policy, and, to be effective, all such changes must be in Writing and Signed by an officer of The Principal. The Principal reserves the right to change this Group Policy as follows: a. Any or all provisions of this Group Policy may be amended or changed at any time, including retroactive changes, to the extent necessary to meet the requirements of any law or any regulation issued by any governmental agency to which this Group Policy is subject. b. Any or all provisions of this Group Policy may be amended or changed at any time when The Principal determines that such amendment is required for consistent application of policy provisions. c. By Written agreement between The Principal and the Policyholder, this Group Policy may be amended or changed at any time as to any of its provisions. Any change to this Group Policy, including, but not limited to, those in regard to coverage, benefits, and participation privileges, may be made without the consent of any Member or Dependent. Payment of premium beyond the effective date of the change constitutes the Policyholder's consent to the change.", 'If this Group Policy terminates for any reason, the Policyholder must: a. notify each Member of the effective date of the termination; and b. refund or otherwise account to each Member all contributions received or withheld from Members for premiums not actually paid to The Principal. This policy has been updated effective January 1, 2014 GC 6005 Section C - Policy Termination, Page 2', "Scheduled Benefit in force for the Member before the change will continue to apply to the Member until the day of return to Active Work. When the Member returns to Active Work, the Scheduled Benefit increase will then be in force for the Member. Any decrease in Scheduled Benefit amounts due to a change by amendment to this Group Policy will be effective on the date of change, whether or not the Member is Actively at Work. (2) A change in the Member's Scheduled Benefit amount because of a change in the Schedule of Insurance (as described in PART IV, Section A) by amendment to this Group Policy for which Proof of Good Health is required (see e. above) will be effective on the later of: - the date the change would have been effective if Proof of Good Health had not been required; or - the date Proof of Good Health is approved by The Principal. h. Effective Date for Benefit Changes Due to Changes Requested by the Member (1) A change in a Member's Scheduled Benefit amount because of a request by the Member for which Proof of Good Health is not required (see e. above) will normally be effective on the date of the request. However, if the Member is not Actively at Work on the date a Scheduled Benefit change would otherwise be effective, the Scheduled Benefit change will not be in force until the date the Member returns to Active Work. Any decrease in Scheduled Benefit amounts due to a request by the Member will be effective on the date of the change, whether or not the Member is Actively at Work. (2) A change in the Member's Scheduled Benefit amount because of a request by the Member for which Proof of Good Health is required (see e. above) will be effective on the later of: - the date the change would have been effective if Proof of Good Health had not been required; or - the date Proof of Good Health is approved by The Principal. i. Effective Date for Benefit Changes Due to Change in the Member's Family Status A Member may request an increase in Scheduled Benefit amount, a decrease in Scheduled Benefits, or the addition of Scheduled Benefits for which he or she was not previously insured if a change in the Member's family status as described below has occurred, provided a request for such increase, decrease, or addition is made in Writing ...
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 100.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Contextual Recall: 100.00% pass rate
# Faithfulness: 75.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval view' to analyze, debug, and save evaluation results on Confident AI.
# ✨ You're running DeepEval's latest Contextual Precision Metric! (using gpt-40, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-40, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Contextual Recall Metric! (using gpt-40, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-40, strict=False, async_mode=True)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because all relevant nodes are ranked higher than irrelevant nodes. The first node is highly relevant because it states, 'the Policyholder must: a. notify each Member of the effective date of the termination; and b. refund or otherwise account to each Member all contributions received or withheld from Members for premiums not actually paid to The Principal,' which directly addresses compliance with GC 6005 Section C. The irrelevant nodes, such as the second node, which focuses on policy renewal, and the third node, which discusses reasons for policy termination without addressing compliance details, are ranked lower, ensuring precision!, error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the response is completely relevant and effectively addresses the input without any irrelevant statements. Great job!, error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the expected output aligns perfectly with the information from the 1st node in the retrieval context. Great job maintaining accuracy and clarity!, error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because there are no contradictions. Great job on ensuring complete faithfulness to the retrieval context!, error: None)
#
# For test case:
#
#   - input: How does the Policyholder ensure compliance with the requirements under GC 6005 Section C when the Group Policy terminates?
#   - actual output: When the Group Policy terminates, the Policyholder must ensure compliance with the requirements under **GC 6005 Section C** by taking the following steps:
#
# 1. **Provide Written Notice to Certificate Holders**
#    The Policyholder must give **written notice** to all Certificate Holders (insured individuals) within **31 days** of the Group Policy’s termination. This notice must inform them of:
#    - The termination of the Group Policy.
#    - Their right to **convert** their coverage to an individual policy without evidence of insurability, if applicable.
#    - The **deadline** (typically **31 days** from the date of termination or notice) to exercise this conversion right.
#
# 2. **Facilitate Conversion Rights (if applicable)**
#    If the policy includes a **conversion privilege**, the Policyholder must:
#    - Ensure Certificate Holders receive the necessary forms and instructions to convert their coverage.
#    - Submit conversion applications to the insurer within the specified timeframe.
#
# 3. **Submit Required Documentation to the Insurer**
#    The Policyholder must provide the insurer with:
#    - A final list of active Certificate Holders as of the termination date.
#    - Any outstanding premium payments or adjustments.
#
# 4. **Comply with State and Regulatory Requirements**
#    The Policyholder must adhere to any additional state-specific regulations regarding policy termination and notice requirements.
#
# By fulfilling these obligations, the Policyholder ensures compliance with **GC 6005 Section C** and protects the rights of Certificate Holders.
#
# ---
# ### **Citations**
# 1. **Part:** *PART II - POLICY ADMINISTRATION*
#    **Section:** *GC 6005 Section C (Termination and Conversion Rights)*
#    **Page:** *16*
#    **Article:** *Article 4 (Termination Procedures)*
#    *(Referenced from: "If this Group Policy terminates for any reason, the Policyholder must notify all Certificate Holders in writing within 31 days...")*
#
# 2. **Part:** *PART II - POLICY ADMINISTRATION*
#    **Section:** *GC 6005 Section C*
#    **Page:** *16*
#    *(Referenced from: "The Policyholder shall provide the insurer with a final list of active Certificate Holders and facilitate conversion rights as outlined in this section.")*
#   - expected output: The Policyholder ensures compliance by notifying Members of the termination date and refunding or accounting for contributions not paid to The Principal.
#   - context: None
#   - retrieval context: ['If this Group Policy terminates for any reason, the Policyholder must: a. notify each Member of the effective date of the termination; and b. refund or otherwise account to each Member all contributions received or withheld from Members for premiums not actually paid to The Principal. This policy has been updated effective January 1, 2014 GC 6005 Section C - Policy Termination, Page 2', 'Insurance under this Group Policy runs annually to the Policy Anniversary, unless sooner terminated. While this Group Policy is in force, and subject to the provisions in PART II, Section C, the Policyholder may renew at the applicable premium rates in effect on the Policy Anniversary. This policy has been updated effective January 1, 2014 GC 6005 A Section D - Policy Renewal, Page 1', 'The Principal may nonrenew or terminate this Group Policy by giving the Policyholder 31 days advance notice in Writing, if the Policyholder: a. ceases to be actively engaged in business for profit within the meaning of the Internal Revenue Code, or be established as a legitimate nonprofit corporation within the meaning of the Internal Revenue Code; or b. fails to maintain the participation percentages requirements of PART II, Section A with respect to eligible employees, excluding those for whom Proof of Good Health is not satisfactory to The Principal; or c. fails to maintain three or more insured employees under this Group Policy; or d. fails to pay premium in accordance with the requirements of PART II, Section B; or e. has performed an act or practice that constitutes fraud or has made an intentional misrepresentation of material fact under the terms of this Group Policy; or f. does not promptly provide The Principal with information that is reasonably required; or g. fails to perform any of its obligations that relate to this Group Policy. This policy has been updated effective January 1, 2014 GC 6005 Section C - Policy Termination, Page 1']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 100.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Contextual Recall: 100.00% pass rate
# Faithfulness: 100.00% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because all relevant nodes, such as the first node which clearly states that a stop-payment order is considered Written notice and explains the termination timing, are perfectly prioritized above irrelevant nodes like the second and third nodes. These irrelevant nodes, while addressing related topics like termination due to non-payment or actions post-termination, do not discuss the implications of a stop-payment order or the timing of termination., error: None)
#   - ✅ Answer Relevancy (score: 0.8888888888888888, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.89 because the response mostly addresses the implications and timing of termination when a stop-payment order is issued, but it includes an irrelevant statement asking if further clarification is needed, which does not contribute directly to answering the question., error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because every sentence in the expected output aligns perfectly with the information provided in the first node in the retrieval context. Great job!, error: None)
#   - ✅ Faithfulness (score: 0.875, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.88 because the actual output incorrectly claims that the Policyholder may terminate the Group Policy at any time, whereas the retrieval context specifies that termination can only occur on the day before any premium due date with written notice., error: None)
#
# For test case:
#
#   - input: If a Policyholder issues a stop-payment order for premiums, what does this imply about their intention to terminate the Group Policy, and when will the termination take effect?
#   - actual output: If you, as a Policyholder, issue a **stop-payment order for premiums**, this action implies your **intention to terminate the Group Policy**. The termination will take effect **at the end of the current policy period** (i.e., the period for which the premium has already been paid).
#
# Here’s how it works:
# - The Group Policy will **not terminate immediately** upon issuing the stop-payment order.
# - Instead, the policy will remain in force until the **end of the paid premium period**.
# - Once that period expires, the policy will **automatically terminate** unless premiums are resumed.
#
# Would you like further clarification on the process?
#
# ---
#
# ### **Citations**
# 1. **Part:** PART II - POLICY ADMINISTRATION
#    **Section:** TERMINATION BY POLICYHOLDER
#    **Article:** Article 4 - Policyholder’s Right to Terminate
#    **Page:** 12
#    *(Reference: "The Policyholder may terminate this Group Policy at any time by giving written notice to the Insurer. Termination will take effect at the end of the period for which premium has been paid.")*
#
# 2. **Part:** PART II - POLICY ADMINISTRATION
#    **Section:** GENERAL TERMINATION PROVISIONS
#    **Article:** Article 1 - Failure to Pay Premiums
#    **Page:** 9
#    *(Reference: "This Group Policy will terminate at the end of the period for which premium has been paid if the Policyholder fails to pay subsequent premiums.")*
#   - expected output: It implies the Policyholder's intention to terminate the Group Policy, and the termination will take effect on the day before the next premium due date.
#   - context: None
#   - retrieval context: ["The Policyholder may terminate this Group Policy effective on the day before any premium due date by giving Written notice to The Principal prior to that premium due date. The Policyholder's issuance of a stop-payment order for any amounts used to pay premiums for the Policyholder's coverage will be considered Written notice from the Policyholder.", 'This Group Policy will terminate at the end of the Grace Period if total premium due has not been received by The Principal before the end of the Grace Period. Failure by the Policyholder to pay the premium within the Grace Period will be deemed notice by the Policyholder to The Principal to discontinue this Group Policy at the end of the Grace Period.', 'If this Group Policy terminates for any reason, the Policyholder must: a. notify each Member of the effective date of the termination; and b. refund or otherwise account to each Member all contributions received or withheld from Members for premiums not actually paid to The Principal. This policy has been updated effective January 1, 2014 GC 6005 Section C - Policy Termination, Page 2']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 100.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Contextual Recall: 100.00% pass rate
# Faithfulness: 100.00% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the first node directly and completely addresses the input question, providing explicit details about the premium rate for Member Accidental Death and Dismemberment Insurance in relation to Member Life Insurance, as well as the impact of having multiple eligible group insurance policies. All relevant information is ranked at the top, and the irrelevant nodes appear lower in the ranking., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the response is fully relevant to the input, with no irrelevant statements distracting from addressing the question. Great job maintaining complete focus!, error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because all sentences in the expected output align perfectly with the nodes in the retrieval context. Great job!, error: None)
#   - ✅ Faithfulness (score: 0.8333333333333334, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.83 because the actual output incorrectly claims that the AD&D premium is calculated as 0.10 per $1,000 of Life coverage, while the retrieval context clearly states the premium rate is $0.025 for each $1,000 of Member Life Insurance in force., error: None)
#
# For test case:
#
#   - input: How does the premium rate for Member Accidental Death and Dismemberment Insurance relate to the Member Life Insurance in force, and what is the impact of having multiple eligible group insurance policies?
#   - actual output: Here’s how the premium rates and coverage interact for your query:
#
# 1. **Premium Rate Relationship Between AD&D and Life Insurance**
#    The premium rate for **Member Accidental Death and Dismemberment (AD&D) Insurance** is directly tied to the amount of **Member Life Insurance** in force. Specifically:
#    - The AD&D coverage amount is typically **equal to the Member Life Insurance amount** you have in force (e.g., if your Life Insurance is $50,000, your AD&D coverage would also be $50,000).
#    - The premium for AD&D is calculated as a **percentage of the Life Insurance premium rate** (e.g., 0.10 per $1,000 of Life coverage). This means your AD&D premium will scale proportionally with your Life Insurance coverage.
#
# 2. **Impact of Multiple Eligible Group Insurance Policies**
#    If you are covered under **multiple eligible group insurance policies** (e.g., through different employers or associations), the following applies:
#    - **Maximum Combined Coverage**: The total AD&D benefit payable across all policies is **capped at a specified limit** (e.g., $500,000). If your combined coverage exceeds this limit, the benefits from each policy will be **prorated** to ensure the total payout does not surpass the maximum.
#    - **No Stacking of Benefits**: You cannot receive the full AD&D benefit from each policy simultaneously. The insurer will coordinate benefits to avoid overpayment.
#
# ---
# ### **Citations**
# 1. **Premium Rate for AD&D Insurance**
#    - *Document*: *"The premium rate(s) for each Member insured for Accidental Death and Dismemberment Insurance shall be equal to the amount of Life Insurance in force, multiplied by the AD&D rate (e.g., 0.10 per $1,000 of Life coverage)."*
#    - **Citation**:
#      ```json
#      {
#        "Section": "Section B - Premiums",
#        "Page": "Not specified"
#      }
#      ```
#
# 2. **Impact of Multiple Group Policies**
#    - *Document*: *"A Member's Accidental Death and Dismemberment Insurance benefit under this policy shall not exceed the maximum combined limit of $500,000 when aggregated with other eligible group policies. Benefits will be prorated if coverage exceeds this limit."*
#    - **Citation**:
#      ```json
#      {
#        "Section": "Section C - Benefit Limitations",
#        "Page": 27
#      }
#      ```
#   - expected output: The premium rate for Member Accidental Death and Dismemberment Insurance is $0.025 for each $1,000 of Member Life Insurance in force. Having at least two other eligible group insurance policies may make the Policyholder eligible for a multiple policy discount.
#   - context: None
#   - retrieval context: ['The premium rate(s) for each Member insured for Life Insurance will be: a. Member Life Insurance $0.210 for each $1,000 of insurance in force. b. Member Accidental Death and Dismemberment Insurance $0.025 for each $1,000 of Member Life Insurance in force. c. Dependent Life Insurance $1.46 for each Member insured for Dependent Life Insurance. If the Policyholder has at least two other eligible group insurance policies underwritten by The Principal, as determined by The Principal, the Policyholder may be eligible for a multiple policy discount.', 'The amount of premium to be paid on each due date will be determined in these ways: a. Member Life Insurance The total volume of insurance in force will be divided by 1,000. The result will then be multiplied by the premium rate then in effect. b. Member Accidental Death and Dismemberment Insurance The total volume of insurance in force will be divided by 1,000. The result will then be multiplied by the premium rate then in effect. c. Dependent Life Insurance This policy has been updated effective January 1, 2014 GC 6004 Section B - Premiums, Page 2', "A Member's Accidental Death and Dismemberment Insurance under this Group Policy will terminate on the earliest of: a. the date his or her Member Life Insurance ceases; or b. the date Member Accidental Death and Dismemberment Insurance is removed from this Group Policy; or c. the date the last premium is paid for the Member's Accidental Death and Dismemberment Insurance; or d. any date desired, if requested by the Member before that date; or e. the date the Member ceases to be in a class for which Member Accidental Death and Dismemberment Insurance is provided."]
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 100.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Contextual Recall: 100.00% pass rate
# Faithfulness: 100.00% pass rate
#
# ======================================================================
#
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because all relevant nodes are perfectly ranked above irrelevant ones. The first node clearly explains 'the reporting responsibilities of the Policyholder' and 'timing of premium adjustments,' which is directly relevant to the input. Meanwhile, the second node focuses on 'clerical errors and adjustments' without detailing reporting responsibilities, and the third node discusses 'adjustments during schedule changes and anniversaries' but omits the Policyholder's reporting duties, making them rightfully ranked lower., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because the output is highly relevant and there are no irrelevant statements, directly addressing the input in a clear and precise manner. Great job!, error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 1.00 because every sentence in the expected output is fully supported by information in the 1st node of the retrieval context. Excellent alignment, well done!, error: None)
#   - ✅ Faithfulness (score: 0.8125, threshold: 0.7, strict: False, evaluation model: gpt-40, reason: The score is 0.81 because the actual output introduces claims that are not fully aligned with the retrieval context, such as requiring the Policyholder to report changes in definitions of 'Member' or 'Dependent', specifying predefined intervals for premium recalculation, and referencing obligations in Article 6. The retrieval context, however, does not support these precise assertions, leading to partial misalignment., error: None)
#
# For test case:
#
#   - input: What are the reporting responsibilities of the Policyholder regarding Members' insurance status, and how do these affect premium adjustments?
#   - actual output: As the Policyholder, you have specific reporting responsibilities regarding Members' insurance status, which directly impact premium adjustments. Here’s what you need to know:
#
# ### **Reporting Responsibilities**
# 1. **Accurate and Timely Reporting of Member Data**
#    You must provide the insurer with accurate information about the number of Members insured under the policy, including any dependents, as of the policy’s effective date and any subsequent changes. This includes:
#    - The number of Members and their dependents (if applicable) at the start of the policy.
#    - Any changes in the definition of a "Member" or "Dependent" during the policy term.
#    - Updates on the number of insured Members or dependents if requested by the insurer.
#
# 2. **Obligation to Respond to Insurer Requests**
#    Upon the insurer’s request, you must furnish details about the insurance status of Members, including:
#    - The total count of insured Members and dependents.
#    - Any modifications to Member eligibility criteria or coverage terms.
#
# 3. **Impact of Reporting on Premium Calculations**
#    Premiums are typically adjusted based on the number of insured Members and dependents. If you fail to report changes accurately or on time:
#    - **Underreporting** (fewer Members than actual) may lead to premium shortfalls, potentially resulting in additional charges or coverage disputes.
#    - **Overreporting** (more Members than actual) may result in unnecessary premium payments, though corrections can be made upon verification.
#    - **Late or incorrect reporting** may delay premium adjustments, leading to discrepancies in billing or coverage.
#
# ### **How Premium Adjustments Work**
# - Premiums are recalculated based on the reported number of insured Members and dependents at predefined intervals (e.g., policy renewal or mid-term adjustments).
# - If the number of insured Members increases, the premium may rise proportionally.
# - If the number decreases, the premium may be reduced, subject to the insurer’s terms.
#
# By fulfilling these reporting obligations accurately and promptly, you ensure fair premium adjustments and avoid potential disputes or coverage issues.
#
# ---
#
# ### **Citations**
# Here are the relevant sections from your policy documents for reference:
#
# 1. **Reporting Requirements for Member Data**
#    - **Part:** PART II - POLICY ADMINISTRATION
#    - **Article:** Article 6 - Information to be Furnished by the Policyholder
#    - **Page:** 13
#    - **Cited Text:**
#      *"The Policyholder must, upon request, give The Company a certificate signed by an authorized officer of the Policyholder stating the number of Members insured for Dependent Life Insurance on any date specified by The Company."*
#      *"The Policyholder must notify The Company of any change in the definition of Member or Dependent during the policy term."*
#
# 2. **Premium Adjustments Based on Member Count**
#    - **Part:** PART II - POLICY ADMINISTRATION
#    - **Page:** 13
#    - **Cited Text:**
#      *"The number of Members insured for Dependent Life Insurance shall be the basis for premium calculations and adjustments."*
#   - expected output: The Policyholder must report eligible Members before or during the month coverage becomes effective, terminated Members within a month of termination, and changes in insurance class within a month of the change. Premium adjustments for changes not on the first of an Insurance Month are applied as if the change occurred on the first of the next Insurance Month.
#   - context: None
#   - retrieval context: ["The number of Members insured for Dependent Life Insurance will be multiplied by the premium rate then in effect. To ensure accurate premium calculations, the Policyholder is responsible for reporting to The Principal, the following information during the stated time periods: a. Members who are eligible to become insured are to be reported during the month prior to or during the month that coverage becomes effective. b. Members whose coverage has terminated are to be reported within a month of the date coverage terminated. c. Changes in Member insurance class are to be reported within a month of the date that the change in insurance class took place. If a Member is added or a present Member's insurance is increased or terminated on other than the first of an Insurance Month, premium for that Member will be adjusted and applied as if the change were to take place on the first of the next following Insurance Month.", 'The Policyholder must, upon request, give The Principal all information needed to administer this Group Policy. If a clerical error is found in this information, The Principal may at any time adjust premium to reflect the facts. An error will not invalidate insurance that would otherwise be in force. Neither will an error continue insurance that would otherwise be terminated. The Principal may inspect, at any reasonable time, all Policyholder records, which relate to this Group Policy.', "b . on any date the definition of Member or Dependent is changed; and c. on any date the Policyholder's business, as specified on the Policyholder application, is changed; and d. on any date that a schedule of insurance or class of insured Members is changed; and e. on any premium due date, if the Policyholder has been receiving a multiple policy discount rate and the Policyholder drops below the minimum number of coverages to receive such discount rate; and f. on any date the premium contribution required of Members is changed; and g. with respect to Member Life Insurance, on any Policy Anniversary, if the average age, average Scheduled Benefit amount, or the male/female distribution for then insured Members has changed since the last Policy Anniversary; and h. on any Policy Anniversary, if the volume of insurance for then insured Members has increased or decreased by more than 25% since the last Policy Anniversary. If the Policyholder has other group insurance with The Principal, and if life coverage is initially added on a date other than the Policy Anniversary and it is more than six months before the next Policy Anniversary, The Principal reserves the right to change the premium rate on the next Policy Anniversary. Written notice will be given to the Policyholder at least 31 days before the date of change. If the Policyholder agrees to participate in the electronic services program of The Principal and, at a later date elects to withdraw from participation, such withdrawal may result in certain administrative fees being charged to the Policyholder."]
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 100.00% pass rate
# Answer Relevancy: 100.00% pass rate
# Contextual Recall: 100.00% pass rate
# Faithfulness: 100.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval view' to analyze, debug, and save evaluation results on Confident AI.

# %%
# all_test_cases_df['contextual_precision'] = [{} for _ in range(len(all_test_cases_df))]
# all_test_cases_df['contextual_recall'] = [{} for _ in range(len(all_test_cases_df))]
# all_test_cases_df['answer_relevancy'] = [{} for _ in range(len(all_test_cases_df))]
# all_test_cases_df['faithfulness'] = [{}for _ in range(len(all_test_cases_df))]

for results in all_results:
    for label, test_results in results:
        if test_results:
            for t in test_results:
                expected_output = t.expected_output
                for m in t.metrics_data:
                    if m.name == "Contextual Precision":
                        all_test_cases_df.loc[all_test_cases_df['expected_output']==expected_output,"contextual_precision"] = [{"score": m.score, "reason": m.reason}]
                    elif m.name == "Answer Relevancy":
                        all_test_cases_df.loc[all_test_cases_df['expected_output']==expected_output,"answer_relevancy"] = [{"score": m.score, "reason": m.reason}]

                    elif m.name == "Contextual Recall":
                        all_test_cases_df.loc[all_test_cases_df['expected_output']==expected_output,"contextual_recall"] =[{"score": m.score, "reason": m.reason}]

                    elif m.name == "Faithfulness":
                        all_test_cases_df.loc[all_test_cases_df['expected_output']==expected_output,"faithfulness"] =[{"score": m.score, "reason": m.reason}]

# %%
all_test_cases_df.to_parquet(os.getenv("OUTPUT_QA"),index=False)

# %%
import pandas as pd
all_test_cases_df = pd.read_parquet(os.getenv("OUTPUT_QA"))

# %%
#Getting all the scores

all_test_cases_df["contextual_precision_score"] = 0
all_test_cases_df["answer_relevancy_score"] = 0
all_test_cases_df["contextual_recall_score"] = 0
all_test_cases_df["faithfulness_score"] = 0

for i in range(0,40):
    all_test_cases_df.loc[i,"contextual_precision_score"] = all_test_cases_df.loc[i,"contextual_precision"]["score"]
    all_test_cases_df.loc[i,"answer_relevancy_score"] = all_test_cases_df.loc[i,"answer_relevancy"]["score"]
    all_test_cases_df.loc[i,"contextual_recall_score"] = all_test_cases_df.loc[i,"contextual_recall"]["score"]
    all_test_cases_df.loc[i,"faithfulness_score"] = all_test_cases_df.loc[i,"faithfulness"]["score"]
# Out:
# C:\Users\paymo\AppData\Local\Temp\ipykernel_11228\3110490606.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   all_test_cases_df.loc[i,"answer_relevancy_score"] = all_test_cases_df.loc[i,"answer_relevancy"]["score"]
# C:\Users\paymo\AppData\Local\Temp\ipykernel_11228\3110490606.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7272727272727273' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   all_test_cases_df.loc[i,"faithfulness_score"] = all_test_cases_df.loc[i,"faithfulness"]["score"]
# C:\Users\paymo\AppData\Local\Temp\ipykernel_11228\3110490606.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   all_test_cases_df.loc[i,"contextual_precision_score"] = all_test_cases_df.loc[i,"contextual_precision"]["score"]

# %%
all_test_cases_df.describe
# Out:
#        contextual_precision_score  answer_relevancy_score  \
# count                   40.000000               40.000000
# mean                     0.962500                0.880828
# std                      0.133373                0.127165
# min                      0.500000                0.454545
# 25%                      1.000000                0.809375
# 50%                      1.000000                0.897368
# 75%                      1.000000                1.000000
# max                      1.000000                1.000000
#
#        contextual_recall_score  faithfulness_score
# count                     40.0           40.000000
# mean                       1.0            0.807301
# std                        0.0            0.206770
# min                        1.0            0.000000
# 25%                        1.0            0.750000
# 50%                        1.0            0.851648
# 75%                        1.0            1.000000
# max                        1.0            1.000000

# %%
all_test_cases_df['query'][0]
# Out:
# "How does the policy define a Member's ability to be considered Actively at Work, and what exceptions are made for short-term absences?"
